# %%
from __future__ import print_function
import pandas as pd
import numpy as np
from PIL import Image
import os
from tqdm import tqdm
# from __future__ import print_function
import argparse
# import numpy  as np
# from PIL import Image
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torch.utils.data.sampler import SubsetRandomSampler
from torchvision import transforms

from data_loaders import Plain_Dataset, eval_data_dataloader
from deep_emotion import Deep_Emotion
from generate_data import Generate_data

# %%
## Data is 48 X 48 --> i converted this into 2304 1D array and have saved it in the csv file along with the labels.

# This generate data class will convert this 1D image back to 2D image and we have read csv file using pandas
class Generate_data():
    
    def __init__(self, datapath):
        """
        Generate_data class
        Two methods to be used
        1-split_test
        2-save_images
        [Note] that you have to split the public and private from fer2013 file
        """
        self.data_path = datapath
        
    def str_to_image(self, str_img = ' '):
        '''
        Convert string pixels from the csv file into image object
            params:- take an image string
            return :- return PIL image object
        '''
        imgarray_str = str_img.split(' ')
        imgarray = np.asarray(imgarray_str,dtype=np.uint8).reshape(48,48)
        return Image.fromarray(imgarray)

    def split_test(self, test_filename = 'finaltest', val_filename= 'val'):
        """
        Helper function to split the validation and test data from general test file as it contains (Public test, Private test)
            params:-
                data_path = path to the folder that contains the test data file
        """
        print("Hello ")
        csv_path = self.data_path +"/"+ 'train.csv'
        print("Hello " + csv_path)
        test = pd.read_csv(csv_path)
        validation_data = pd.DataFrame(test.iloc[:30589,:])
        test_data = pd.DataFrame(test.iloc[30589:,:])
        test_data.to_csv(self.data_path+"/"+test_filename+".csv")
        validation_data.to_csv(self.data_path+"/"+val_filename+".csv")
        print("Done splitting the test file into validation & final test file")

    

    def save_images(self, datatype='train'):
        '''
        save_images is a function responsible for saving images from data files e.g(train, test) in a desired folder
            params:-
            datatype= str e.g (train, val, finaltest)
        '''
        foldername= self.data_path+"/"+datatype
        csvfile_path= self.data_path+"/"+datatype+'.csv'
        if not os.path.exists(foldername):
            os.mkdir(foldername)

        data = pd.read_csv(csvfile_path)
        images = data['pixels'] #dataframe to series pandas
        numberofimages = images.shape[0]
        for index in tqdm(range(numberofimages)):
            img = self.str_to_image(images[index])
            img.save(os.path.join(foldername,'{}{}.jpg'.format(datatype,index)),'JPEG')
        print('Done saving {} data'.format((foldername)))

# %%
generate_dataset = Generate_data('./data')
generate_dataset.split_test()
generate_dataset.save_images()
generate_dataset.save_images('finaltest')
generate_dataset.save_images('val')
# Out:
# Hello
# Hello ./data/train.csv
# Done splitting the test file into validation & final test file
# 100%|██████████| 35887/35887 [00:14<00:00, 2540.38it/s]
# Done saving ./data/train data
# 100%|██████████| 5298/5298 [00:02<00:00, 2554.24it/s]
# Done saving ./data/finaltest data
# 100%|██████████| 30589/30589 [00:11<00:00, 2570.83it/s]
# Done saving ./data/val data

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
def Train(epochs,train_loader,val_loader,criterion,optmizer,device):
    '''
    Training Loop
    '''
    print("===================================Start Training===================================")
    for e in range(epochs):
        train_loss = 0
        validation_loss = 0
        train_correct = 0
        val_correct = 0
        # Train the model  #
        net.train() ## FOr training the model
        for data, labels in train_loader:
            data, labels = data.to(device), labels.to(device)
            optmizer.zero_grad() ## Initializing the gradient/
            outputs = net(data)
            loss = criterion(outputs,labels)
            loss.backward()
            optmizer.step()
            train_loss += loss.item()
            _, preds = torch.max(outputs,1)
            train_correct += torch.sum(preds == labels.data)

        #validate the model#
        net.eval()
        for data,labels in val_loader:
            data, labels = data.to(device), labels.to(device)
            val_outputs = net(data)
            val_loss = criterion(val_outputs, labels)
            validation_loss += val_loss.item()
            _, val_preds = torch.max(val_outputs,1)
            val_correct += torch.sum(val_preds == labels.data)

        train_loss = train_loss/len(train_dataset)
        train_acc = train_correct.double() / len(train_dataset)
        validation_loss =  validation_loss / len(validation_dataset)
        val_acc = val_correct.double() / len(validation_dataset)
        print('Epoch: {} \tTraining Loss: {:.8f} \tValidation Loss {:.8f} \tTraining Acuuarcy {:.3f}% \tValidation Acuuarcy {:.3f}%'
                                                           .format(e+1, train_loss,validation_loss,train_acc * 100, val_acc*100))

    torch.save(net.state_dict(),'deep_emotion-{}-{}-{}.pt'.format(epochs,batchsize,lr))
    print("===================================Training Finished===================================")



# if __name__ == '__main__':
#     parser = argparse.ArgumentParser(description="Configuration of setup and training process")
#     parser.add_argument('-s', '--setup', type=bool, help='setup the dataset for the first time')
#     parser.add_argument('-d', '--data', type=str,required= True,
#                                help='data folder that contains data files that downloaded from kaggle (train.csv and test.csv)')
#     parser.add_argument('-hparams', '--hyperparams', type=bool,
#                                help='True when changing the hyperparameters e.g (batch size, LR, num. of epochs)')
#     parser.add_argument('-e', '--epochs', type= int, help= 'number of epochs')
#     parser.add_argument('-lr', '--learning_rate', type= float, help= 'value of learning rate')
#     parser.add_argument('-bs', '--batch_size', type= int, help= 'training/validation batch size')
#     parser.add_argument('-t', '--train', type=bool, help='True when training')
#     args = parser.parse_args()

#     if args.setup :
#         generate_dataset = Generate_data(args.data)
#         generate_dataset.split_test()
#         generate_dataset.save_images()
#         generate_dataset.save_images('finaltest')
#         generate_dataset.save_images('val')

#     if args.hyperparams:
#         epochs = args.epochs
#         lr = args.learning_rate
#         batchsize = args.batch_size
#     else :
#         epochs = 100
#         lr = 0.005
#         batchsize = 128

#     if args.train:
#         net = Deep_Emotion()
#         net.to(device)
#         print("Model archticture: ", net)
#         traincsv_file = args.data+'/'+'train.csv'
#         validationcsv_file = args.data+'/'+'val.csv'
#         train_img_dir = args.data+'/'+'train/'
#         validation_img_dir = args.data+'/'+'val/'

# %%
epochs = 100
lr = 0.005 # Learning rate
batchsize = 128
net = Deep_Emotion() ## CREATING THE MODEL BY CALLING DEEPMOTION.PY
net.to(device) ## MOVING IT TO GPU / CPU
print("Model archticture: ", net)
traincsv_file = 'data' + '/' + 'train.csv'
validationcsv_file = 'data' + '/' + 'val.csv'
train_img_dir = 'data' + '/' + 'train/'
validation_img_dir = 'data' + '/' + 'val/'    
        


transformation= transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.5,),(0.5,))])
train_dataset= Plain_Dataset(csv_file=traincsv_file, img_dir = train_img_dir, datatype = 'train', transform = transformation)
validation_dataset= Plain_Dataset(csv_file=validationcsv_file, img_dir = validation_img_dir, datatype = 'val', transform = transformation)
train_loader= DataLoader(train_dataset,batch_size=batchsize,shuffle = True,num_workers=0)
val_loader=   DataLoader(validation_dataset,batch_size=batchsize,shuffle = True,num_workers=0)

criterion= nn.CrossEntropyLoss()
optmizer= optim.Adam(net.parameters(),lr= lr)
Train(epochs, train_loader, val_loader, criterion, optmizer, device)
# Out:
# Model archticture:  Deep_Emotion(
#   (conv1): Conv2d(1, 10, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#   (conv4): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#   (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (norm): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=810, out_features=50, bias=True)
#   (fc2): Linear(in_features=50, out_features=7, bias=True)
#   (localization): Sequential(
#     (0): Conv2d(1, 8, kernel_size=(7, 7), stride=(1, 1))
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(8, 10, kernel_size=(5, 5), stride=(1, 1))
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): ReLU(inplace=True)
#   )
#   (fc_loc): Sequential(
#     (0): Linear(in_features=640, out_features=32, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=32, out_features=6, bias=True)
#   )
# )
# ===================================Start Training===================================
# /Users/gaurishanand/opt/anaconda3/lib/python3.8/site-packages/torch/nn/functional.py:3890: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# /Users/gaurishanand/opt/anaconda3/lib/python3.8/site-packages/torch/nn/functional.py:3828: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# Epoch: 1 	Training Loss: 0.01291888 	Validation Loss 0.01446997 	Training Acuuarcy 34.258% 	Validation Acuuarcy 26.686%
# Epoch: 2 	Training Loss: 0.01164019 	Validation Loss 0.01161177 	Training Acuuarcy 42.196% 	Validation Acuuarcy 42.944%
# Epoch: 3 	Training Loss: 0.01114551 	Validation Loss 0.01120802 	Training Acuuarcy 44.935% 	Validation Acuuarcy 44.823%
# Epoch: 4 	Training Loss: 0.01094053 	Validation Loss 0.01078001 	Training Acuuarcy 45.953% 	Validation Acuuarcy 46.595%
# Epoch: 5 	Training Loss: 0.01076730 	Validation Loss 0.01057801 	Training Acuuarcy 46.922% 	Validation Acuuarcy 47.713%
# Epoch: 6 	Training Loss: 0.01061157 	Validation Loss 0.01056341 	Training Acuuarcy 47.694% 	Validation Acuuarcy 48.498%
# Epoch: 7 	Training Loss: 0.01051835 	Validation Loss 0.01077708 	Training Acuuarcy 47.889% 	Validation Acuuarcy 47.272%
# Epoch: 8 	Training Loss: 0.01047074 	Validation Loss 0.01098644 	Training Acuuarcy 48.527% 	Validation Acuuarcy 45.556%
# Epoch: 9 	Training Loss: 0.01040398 	Validation Loss 0.01033620 	Training Acuuarcy 48.773% 	Validation Acuuarcy 49.090%
# Epoch: 10 	Training Loss: 0.01033672 	Validation Loss 0.01017761 	Training Acuuarcy 49.316% 	Validation Acuuarcy 49.881%
# Epoch: 11 	Training Loss: 0.01021591 	Validation Loss 0.01029112 	Training Acuuarcy 49.987% 	Validation Acuuarcy 49.295%
# Epoch: 12 	Training Loss: 0.01018780 	Validation Loss 0.01001780 	Training Acuuarcy 49.848% 	Validation Acuuarcy 50.969%
# Epoch: 13 	Training Loss: 0.01011000 	Validation Loss 0.01020390 	Training Acuuarcy 50.403% 	Validation Acuuarcy 49.926%
# Epoch: 14 	Training Loss: 0.01008628 	Validation Loss 0.01006656 	Training Acuuarcy 50.472% 	Validation Acuuarcy 50.590%
# Epoch: 15 	Training Loss: 0.01005985 	Validation Loss 0.01004091 	Training Acuuarcy 50.751% 	Validation Acuuarcy 50.747%
# Epoch: 16 	Training Loss: 0.00998920 	Validation Loss 0.00994708 	Training Acuuarcy 50.832% 	Validation Acuuarcy 51.041%
# Epoch: 17 	Training Loss: 0.00995703 	Validation Loss 0.01016279 	Training Acuuarcy 51.169% 	Validation Acuuarcy 49.596%
# Epoch: 18 	Training Loss: 0.00995428 	Validation Loss 0.00978444 	Training Acuuarcy 51.331% 	Validation Acuuarcy 52.094%
# Epoch: 82 	Training Loss: 0.00916263 	Validation Loss 0.00907778 	Training Acuuarcy 55.223% 	Validation Acuuarcy 55.974%
# Epoch: 83 	Training Loss: 0.00914684 	Validation Loss 0.00909478 	Training Acuuarcy 55.505% 	Validation Acuuarcy 55.517%
# Epoch: 84 	Training Loss: 0.00908721 	Validation Loss 0.00904957 	Training Acuuarcy 55.786% 	Validation Acuuarcy 55.984%
# Epoch: 85 	Training Loss: 0.00914630 	Validation Loss 0.00912713 	Training Acuuarcy 55.733% 	Validation Acuuarcy 55.445%
# Epoch: 86 	Training Loss: 0.00913454 	Validation Loss 0.00912564 	Training Acuuarcy 55.435% 	Validation Acuuarcy 55.883%
# Epoch: 87 	Training Loss: 0.00915636 	Validation Loss 0.00951506 	Training Acuuarcy 55.691% 	Validation Acuuarcy 53.709%
# Epoch: 88 	Training Loss: 0.00913840 	Validation Loss 0.00913334 	Training Acuuarcy 55.521% 	Validation Acuuarcy 55.562%
# Epoch: 89 	Training Loss: 0.00913821 	Validation Loss 0.00915578 	Training Acuuarcy 55.488% 	Validation Acuuarcy 55.500%
# Epoch: 90 	Training Loss: 0.00909289 	Validation Loss 0.00919399 	Training Acuuarcy 55.848% 	Validation Acuuarcy 55.311%
# Epoch: 91 	Training Loss: 0.00915409 	Validation Loss 0.00906284 	Training Acuuarcy 55.452% 	Validation Acuuarcy 55.582%
# Epoch: 92 	Training Loss: 0.00913147 	Validation Loss 0.00928324 	Training Acuuarcy 55.652% 	Validation Acuuarcy 54.847%
# Epoch: 93 	Training Loss: 0.00909727 	Validation Loss 0.00909206 	Training Acuuarcy 55.761% 	Validation Acuuarcy 55.634%
# Epoch: 94 	Training Loss: 0.00914604 	Validation Loss 0.00901042 	Training Acuuarcy 55.432% 	Validation Acuuarcy 56.095%
# Epoch: 95 	Training Loss: 0.00912990 	Validation Loss 0.00907256 	Training Acuuarcy 55.524% 	Validation Acuuarcy 55.834%
# Epoch: 96 	Training Loss: 0.00911629 	Validation Loss 0.00899234 	Training Acuuarcy 55.825% 	Validation Acuuarcy 56.357%
# Epoch: 97 	Training Loss: 0.00907745 	Validation Loss 0.00910982 	Training Acuuarcy 55.965% 	Validation Acuuarcy 55.638%
# Epoch: 98 	Training Loss: 0.00904751 	Validation Loss 0.00893412 	Training Acuuarcy 56.165% 	Validation Acuuarcy 56.703%
# Epoch: 99 	Training Loss: 0.00915399 	Validation Loss 0.00905183 	Training Acuuarcy 55.848% 	Validation Acuuarcy 55.569%
# Epoch: 100 	Training Loss: 0.00903292 	Validation Loss 0.00898945 	Training Acuuarcy 55.903% 	Validation Acuuarcy 56.059%
# ===================================Training Finished===================================

# %% [markdown]
# ## TESTING OF MODEL

# %%
mapping = {
    0 : 'Angry', 
    1 : 'Disgust', 
    2 : 'Fear', 
    3 : 'Happy', 
    4 : 'Sad', 
    5 : 'Surprise', 
    6 : 'Neutral'
}

# %%
net = Deep_Emotion() # In pytorch we have to first load the model

# %%
file_name = 'deep_emotion-100-128-0.005.pt'.format(epochs,batchsize,lr)

# %%
net.load_state_dict(torch.load(file_name))
net.to(device)
# Out:
# Deep_Emotion(
#   (conv1): Conv2d(1, 10, kernel_size=(3, 3), stride=(1, 1))
#   (conv2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#   (conv4): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#   (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (norm): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=810, out_features=50, bias=True)
#   (fc2): Linear(in_features=50, out_features=7, bias=True)
#   (localization): Sequential(
#     (0): Conv2d(1, 8, kernel_size=(7, 7), stride=(1, 1))
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(8, 10, kernel_size=(5, 5), stride=(1, 1))
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): ReLU(inplace=True)
#   )
#   (fc_loc): Sequential(
#     (0): Linear(in_features=640, out_features=32, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=32, out_features=6, bias=True)
#   )
# )

# %%
import cv2
import matplotlib.pyplot as plt

# %%
frame = cv2.imread('./samples/surprise.jpeg')
plt.imshow(cv2.cvtColor(frame,cv2.COLOR_BGR2RGB))

# %%
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
facces = faceCascade.detectMultiScale(gray,1.1,4)

# %%
for x,y,w,h in facces:
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = frame[y:y+h, x:x+w]
    cv2.rectangle(frame, (x,y),(x+w,y+h),(255,0,0),2)
    facess = faceCascade.detectMultiScale(roi_gray)
    if len(facess)==0:
        print("Face not detected")
    else:
        for(ex,ey,ew,eh) in facess:
            face_roi = roi_color[ey:ey+eh,ex:ex+ew]

# %%
plt.imshow(cv2.cvtColor(frame,cv2.COLOR_BGR2RGB))

# %%
plt.imshow(face_roi) # It will show the cropped face i.e we will get only the required feature from the image

# %%
face_roi.shape
# Out:
# (98, 98, 3)

# %%
gray = cv2.cvtColor(face_roi, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (98, 98)

# %%
final_image = cv2.resize(gray, (48,48))
final_image.shape
# Out:
# (48, 48)

# %%
final_image = np.expand_dims(final_image,axis = 0) ## need third dimension

# %%
final_image.shape
# Out:
# (1, 48, 48)

# %%
final_image = np.expand_dims(final_image,axis = 0) ## need fourth dimension

# %%
final_image.shape
# Out:
# (1, 1, 48, 48)

# %%
final_image = final_image / 255.0 ## Normalizing step

# %%
dataa = torch.from_numpy(final_image)

# %%
dataa = dataa.type(torch.FloatTensor)

# %%
dataa = dataa.to(device)

# %%
outputs = net(dataa)
pred = F.softmax(outputs,dim=1)

# %%
print(pred)
# Out:
# tensor([[0.0095, 0.0022, 0.4643, 0.0009, 0.0220, 0.4884, 0.0126]],
#        grad_fn=<SoftmaxBackward>)

# %%
print('prediction = ' + mapping[int(torch.argmax(pred))])
# Out:
# prediction = Surprise

# %% [markdown]
# ## Now we will see another example

# %%
frame = cv2.imread('./samples/disgusting.jpeg')
plt.imshow(cv2.cvtColor(frame,cv2.COLOR_BGR2RGB))
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
facces = faceCascade.detectMultiScale(gray,1.1,4)
for x,y,w,h in facces:
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = frame[y:y+h, x:x+w]
    cv2.rectangle(frame, (x,y),(x+w,y+h),(255,0,0),2)
    facess = faceCascade.detectMultiScale(roi_gray)
    if len(facess)==0:
        print("Face not detected")
    else:
        for(ex,ey,ew,eh) in facess:
            face_roi = roi_color[ey:ey+eh,ex:ex+ew]

plt.imshow(cv2.cvtColor(frame,cv2.COLOR_BGR2RGB))

# %%
plt.imshow(face_roi)
gray = cv2.cvtColor(face_roi, cv2.COLOR_BGR2GRAY)
final_image = cv2.resize(gray, (48,48))
final_image = np.expand_dims(final_image,axis = 0)
final_image = np.expand_dims(final_image,axis = 0)
final_image = final_image / 255.0
dataa = torch.from_numpy(final_image)
dataa = dataa.type(torch.FloatTensor)
dataa = dataa.to(device)
outputs = net(dataa)
pred = F.softmax(outputs,dim=1)
print('prediction = ' + mapping[int(torch.argmax(pred))])
# Out:
# prediction = Disgust

# %% [markdown]
# ## 3rd EXAMPLE

# %%
frame = cv2.imread('./samples/sad.jpeg')
plt.imshow(cv2.cvtColor(frame,cv2.COLOR_BGR2RGB))
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
facces = faceCascade.detectMultiScale(gray,1.1,4)
for x,y,w,h in facces:
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = frame[y:y+h, x:x+w]
    cv2.rectangle(frame, (x,y),(x+w,y+h),(255,0,0),2)
    facess = faceCascade.detectMultiScale(roi_gray)
    if len(facess)==0:
        print("Face not detected")
    else:
        for(ex,ey,ew,eh) in facess:
            face_roi = roi_color[ey:ey+eh,ex:ex+ew]

plt.imshow(cv2.cvtColor(frame,cv2.COLOR_BGR2RGB))

# %%
plt.imshow(face_roi)
gray = cv2.cvtColor(face_roi, cv2.COLOR_BGR2GRAY)
final_image = cv2.resize(gray, (48,48))
final_image = np.expand_dims(final_image,axis = 0)
final_image = np.expand_dims(final_image,axis = 0)
final_image = final_image / 255.0
dataa = torch.from_numpy(final_image)
dataa = dataa.type(torch.FloatTensor)
dataa = dataa.to(device)
outputs = net(dataa)
pred = F.softmax(outputs,dim=1)
print('prediction = ' + mapping[int(torch.argmax(pred))])
# Out:
# prediction = Neutral

# %% [markdown]
# ## LIVE WEBCAM

# %%
import cv2
path = "haarcascade_frontalface_default.xml"
font_scale = 1.5
font = cv2.FONT_HERSHEY_PLAIN

# SET THE RECTANGLE BACKGROUND TO WHITE
rectangle_bgr = (255,255,255)

# MAKE A BLACK IMAGE
img = np.zeros((500,500))

# SET SOME TEXT
text = "Some text in a box!"

# Get the width and height of the text box
(text_width, text_height) = cv2.getTextSize(text,font,fontScale=font_scale,thickness=1)[0]

# Set the text start position
text_offset_x = 10
text_offset_y = img.shape[0] - 25

# make the coords of the box with a small padding of 2 pixels
box_coords = ((text_offset_x,text_offset_y),(text_offset_x + text_width + 2,text_offset_y - text_width - 2))
cv2.rectangle(img,box_coords[0],box_coords[1],rectangle_bgr,cv2.FILLED)
cv2.putText(img,text,(text_offset_x,text_offset_y),font,fontScale=font_scale,color = (0,0,0),thickness = 1)

cap = cv2.VideoCapture(1)
# Check if the webcam is opened correctly
if not cap.isOpened():
    cap = cv2.VideoCapture(0)

if not cap.isOpened():
    raise IOError("Cannot open webcam")
    
while True:
    ret,frame = cap.read()
    
    faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    facces = faceCascade.detectMultiScale(gray,1.1,4)
    for x,y,w,h in facces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = frame[y:y+h, x:x+w]
        cv2.rectangle(frame, (x,y),(x+w,y+h),(255,0,0),2)
        facess = faceCascade.detectMultiScale(roi_gray)
        if len(facess)==0:
            print("Face not detected")
        else:
            for(ex,ey,ew,eh) in facess:
                face_roi = roi_color[ey:ey+eh,ex:ex+ew] # CROPPING THE FACE

    gray = cv2.cvtColor(face_roi, cv2.COLOR_BGR2GRAY)
    final_image = cv2.resize(gray, (48,48))
    final_image = np.expand_dims(final_image,axis = 0)
    final_image = np.expand_dims(final_image,axis = 0)
    final_image = final_image / 255.0
    dataa = torch.from_numpy(final_image)
    dataa = dataa.type(torch.FloatTensor)
    dataa = dataa.to(device)
    outputs = net(dataa)
    pred = F.softmax(outputs,dim=1)
    prediction = mapping[int(torch.argmax(pred))]
    print('prediction = ' + prediction)
    
    font = cv2.FONT_HERSHEY_SIMPLEX
    font_scale = 1.5
    #HELLO
    font = cv2.FONT_HERSHEY_PLAIN
# Out:
# prediction = Neutral
# prediction = Neutral
# prediction = Neutral
# prediction = Neutral
# prediction = Neutral
# Face not detected
# Face not detected
# prediction = Neutral
# prediction = Neutral
# prediction = Neutral
# prediction = Neutral
# prediction = Neutral
# prediction = Neutral
# prediction = Neutral
# Face not detected
# prediction = Neutral
# prediction = Neutral
# prediction = Neutral
# prediction = Neutral
# prediction = Neutral
# prediction = Neutral
# prediction = Neutral
# Face not detected
# prediction = Neutral
# Face not detected
# prediction = Neutral
# Face not detected
# prediction = Neutral
# prediction = Neutral
# Face not detected
# prediction = Neutral
# prediction = Neutral
# prediction = Neutral
# prediction = Neutral
# prediction = Neutral
# Face not detected
# prediction = Disgust
# Face not detected
# prediction = Neutral
# prediction = Angry
# prediction = Fear
# Face not detected
# prediction = Angry
# prediction = Fear
# prediction = Neutral
# prediction = Neutral
# prediction = Neutral
# prediction = Sad
# Face not detected
# prediction = Neutral
# prediction = Neutral
# prediction = Happy
# Face not detected
# prediction = Neutral
# prediction = Happy
# prediction = Neutral
# Face not detected
# prediction = Sad
# Face not detected
# prediction = Neutral
# prediction = Neutral
# prediction = Happy
# Face not detected
# prediction = Neutral
# Face not detected
# prediction = Fear
# prediction = Neutral
# prediction = Happy
# prediction = Neutral
# prediction = Sad
# Face not detected
# Face not detected
# prediction = Neutral
# prediction = Neutral
# Face not detected
# Face not detected
# prediction = Neutral
# Face not detected
# prediction = Neutral
# prediction = Sad
# prediction = Fear
# Face not detected
# prediction = Sad
# prediction = Fear
# prediction = Disgust
# prediction = Fear
# prediction = Neutral
# prediction = Fear
# prediction = Happy
# prediction = Fear
# prediction = Fear
# prediction = Happy
# prediction = Fear
# prediction = Happy
# prediction = Angry
# prediction = Neutral
# prediction = Fear
# prediction = Neutral
# prediction = Fear
# prediction = Neutral
# prediction = Fear
# prediction = Fear
# prediction = Angry
# prediction = Neutral
# Face not detected
# prediction = Fear
# prediction = Happy
# prediction = Fear
# prediction = Fear
# prediction = Disgust
# prediction = Fear
# prediction = Fear
# prediction = Angry
# prediction = Fear
# prediction = Fear
# prediction = Neutral
# prediction = Fear
# prediction = Fear
# prediction = Neutral
# Face not detected
# prediction = Fear
# prediction = Sad
# prediction = Disgust
# prediction = Fear
# Face not detected
# prediction = Fear
# prediction = Disgust
# prediction = Fear
# prediction = Angry
# prediction = Sad
# prediction = Fear
# prediction = Neutral
# Face not detected
# prediction = Neutral
# prediction = Fear
# prediction = Neutral
# prediction = Happy
# prediction = Neutral
# prediction = Angry
# prediction = Neutral
# prediction = Angry
# prediction = Happy
# Face not detected
# prediction = Happy
# Face not detected
# Face not detected
# prediction = Happy
# prediction = Sad
# Face not detected
# prediction = Sad
# prediction = Happy
# Face not detected
# prediction = Happy
# prediction = Happy
# Face not detected
# prediction = Happy
# prediction = Happy
# prediction = Happy
# prediction = Fear
# prediction = Angry
# Face not detected
# prediction = Angry
# prediction = Angry
# prediction = Neutral
# prediction = Happy
# prediction = Disgust
# prediction = Neutral
# prediction = Sad
# prediction = Happy
# prediction = Happy
# prediction = Happy
# prediction = Happy
# Face not detected
# prediction = Happy
# Face not detected
# prediction = Fear
# Face not detected
# prediction = Happy
# Face not detected
# prediction = Happy
# prediction = Sad
# prediction = Happy
# prediction = Sad
# prediction = Happy
# prediction = Happy
# prediction = Sad
# Face not detected
# prediction = Fear
# Face not detected
# prediction = Happy
# Face not detected
# prediction = Fear
# Face not detected
# prediction = Happy
# Face not detected
# prediction = Fear
# Face not detected
# Face not detected
# prediction = Happy
# Face not detected
# prediction = Fear
# prediction = Neutral
# Face not detected
# prediction = Angry
# Face not detected
# prediction = Sad
# Face not detected
# Face not detected
# prediction = Sad
# prediction = Sad
# prediction = Sad
# prediction = Sad
# prediction = Sad
# Face not detected
# prediction = Angry
# prediction = Sad
# prediction = Sad
# prediction = Angry
# prediction = Sad
# prediction = Fear
# prediction = Sad
# prediction = Happy
# prediction = Happy
# prediction = Sad
# Face not detected
# Face not detected
# prediction = Angry
# Face not detected
# prediction = Sad
# Face not detected
# prediction = Surprise
# Face not detected
# Face not detected
# prediction = Angry
# Face not detected
# prediction = Angry
# prediction = Angry
# Face not detected
# prediction = Angry
# prediction = Angry
# prediction = Sad
# prediction = Sad
# Face not detected
# prediction = Angry
# Face not detected
# prediction = Angry
# Face not detected
# prediction = Angry
# Face not detected
# prediction = Angry
# Face not detected
# prediction = Angry
# Face not detected
# Face not detected
# prediction = Sad
# prediction = Angry
# Face not detected
# prediction = Fear
# Face not detected
# prediction = Angry
# Face not detected
# Face not detected
# prediction = Angry
# Face not detected
# prediction = Angry
# Face not detected
# prediction = Sad
# prediction = Angry
# prediction = Angry
# Face not detected
# prediction = Angry
# Face not detected
# prediction = Angry
# Face not detected
# prediction = Fear
# prediction = Sad
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-92-43097380f855> in <module>
#      38     faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
#      39     gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
# ---> 40     facces = faceCascade.detectMultiScale(gray,1.1,4)
#      41     for x,y,w,h in facces:
#      42         roi_gray = gray[y:y+h, x:x+w]
#
# KeyboardInterrupt:
